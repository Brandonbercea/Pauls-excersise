# %% [markdown]
# # PAULS EXCERSISE PROGRAM!
#
# #### Requirements
#
# - Using the data types you’ve learned, we’re going to make an excercise chooser.
# - The excercises consist of 2 categories, 3 subcategories in each, and three levels of difficulty.
# - The two main categories are strengthening and stretching.
# - The subcategories are, lying, side, and standing.
# - The difficulties are L1, L2, and L3.
# - Using the data types you have learned, write a python script that will take inputs of how many strengthening excercises you want and how many stretches you want.
# - It should then pick 70% of the excercises from L1 and 30% of the excercises from L2. Randomly.

# %% [markdown]
# ## Approach
# 1. I will use data types like sequences for ordered items, to keep track of what to do and in what order.
# mapping types for personalization, and identification.
# text types for writing text on the page describing the excersize.

# %%
L1_strengthening = "posterior pelvic tilt laying", "wall sitting standing", "incline side plank side"
print(L1_strengthening)
# Out:
# ('posterior pelvic tilt laying', 'wall sitting standing', 'incline side plank side')

# %%
diastasis_recti_exercises = {
    "Level 1 (Beginners)": [
        {
            "name": "Diaphragmatic Breathing",
            "description": "Focuses on expanding the belly while breathing to activate transverse abdominis."
        },
        {
            "name": "Abdominal Braces",
            "description": "Similar to diaphragmatic breathing but involves holding the exhaled position."
        },
        {
            "name": "Posterior Pelvic Tilt",
            "description": "Activates deep core muscles by tilting the pelvis posteriorly."
        },
        {
            "name": "The Scared Cat",
            "description": "A fundamental core strength exercise focusing on bracing the core from a prone position."
        },
        {
            "name": "Quadruped Arm Raises",
            "description": "Adds balance by raising one arm while maintaining core stability."
        },
        {
            "name": "Modified Side Plank",
            "description": "Supports side plank with knees bent to train the obliques and core."
        },
        {
            "name": "Clam Shells",
            "description": "Hip abduction exercise that stabilizes the core."
        },
        {
            "name": "Modified Side Plank Dips",
            "description": "Dynamic movement added to side plank to further strengthen the obliques."
        },
        {
            "name": "Sitting Single Leg Raises",
            "description": "Performed in a sitting position to challenge core activation with straight legs."
        },
        {
            "name": "Incline Planks",
            "description": "Plank variation using a chair to introduce core engagement while preventing stress on the rectus."
        }
    ],
    "Level 2 (Intermediate)": [
        {
            "name": "Glute Bridge",
            "description": "Fundamental exercise for hip extension and core activation."
        },
        {
            "name": "The Dead Bug",
            "description": "Involves opposite arm and leg extensions to engage core muscles."
        },
        {
            "name": "Feet Elevated Glute Bridge",
            "description": "An advanced glute bridge with feet elevated for deeper hip extension."
        },
        {
            "name": "Supine Leg Curl",
            "description": "A challenging glute bridge variation to activate the core and hamstrings."
        },
        {
            "name": "Split Stance One Arm Shoulder Press",
            "description": "A standing exercise to engage core and upper body muscles."
        },
        {
            "name": "Wall Plank",
            "description": "A more challenging standing plank performed on elbows, focusing on core stability."
        },
        {
            "name": "The Side Plank",
            "description": "Full side plank with straight legs, challenging the obliques and balance."
        },
        {
            "name": "Side Plank Dips",
            "description": "Introduces dynamic movement to further strengthen core and obliques."
        },
        {
            "name": "Side Plank Rotations",
            "description": "Adds rotation to the side plank for enhanced balance and coordination."
        },
        {
            "name": "Quadruped Hip Extensions",
            "description": "Teaches core engagement while activating the hips and glutes."
        }
    ],
    "Level 3 (Advanced)": [
        {
            "name": "Modified Plank with Bent Knee",
            "description": "An advanced plank variation, performed with one knee on the floor for increased core engagement."
        },
        {
            "name": "Modified Plank Balance on Tippy Toes",
            "description": "Involves balancing on tippy toes in a plank, increasing difficulty."
        },
        {
            "name": "Penguins",
            "description": "A side-bending exercise to touch ipsilateral heel while activating core muscles."
        },
        {
            "name": "Side Plank Leg Abductions",
            "description": "A challenging side plank variation that involves lifting the top leg to work obliques and balance."
        },
        {
            "name": "Star Side Plank",
            "description": "Involves abducting the top leg and raising the top arm for additional core and balance demands."
        },
        {
            "name": "Lying Windscreen Wiper (Knees Bent)",
            "description": "A rotational exercise targeting obliques."
        },
        {
            "name": "3 Limb Plank",
            "description": "Increases strength and balance demands by lifting one limb off the ground in a plank."
        },
        {
            "name": "Up and Down Plank",
            "description": "Alternates between forearm and push-up plank positions for core and stability strength."
        },
        {
            "name": "One-Leg Glute Bridge (Knee Bent)",
            "description": "A progression of the glute bridge performed with one leg elevated to increase difficulty."
        },
        {
            "name": "Reverse Lunge",
            "description": "Strengthens the legs and core while teaching stabilization."
        }
    ]
}

# %%
diastasis_recti_exercises_by_position = {
    "Lying Down": {
        "Strength": [
            {
                "name": "Diaphragmatic Breathing",
                "description": "Activates the transverse abdominis through focused breathing."
            },
            {
                "name": "Abdominal Braces",
                "description": "Bracing core muscles by holding the exhaled position."
            },
            {
                "name": "Posterior Pelvic Tilt",
                "description": "Engages deep core muscles through pelvic tilting."
            },
            {
                "name": "Glute Bridge",
                "description": "Strengthens the core and glutes through hip extension."
            },
            {
                "name": "The Dead Bug",
                "description": "Strengthens core by alternating arm and leg extensions."
            },
            {
                "name": "Feet Elevated Glute Bridge",
                "description": "An advanced glute bridge with feet elevated for increased difficulty."
            },
            {
                "name": "One-Leg Glute Bridge (Knee Bent)",
                "description": "Single-leg version of the glute bridge for added difficulty."
            },
            {
                "name": "Penguins",
                "description": "Side-bending exercise to target obliques while lying down."
            },
            {
                "name": "Modified Hollow Body Hold",
                "description": "Core hold exercise engaging upper and lower abs."
            },
            {
                "name": "Lying Windscreen Wiper (Knees Bent)",
                "description": "A rotational exercise that targets the obliques."
            }
        ],
        "Stretch": []
    },
    "Side": {
        "Strength": [
            {
                "name": "Modified Side Plank",
                "description": "A basic side plank to engage obliques with bent knees."
            },
            {
                "name": "Side Plank",
                "description": "Full side plank to challenge obliques and balance."
            },
            {
                "name": "Side Plank Dips",
                "description": "Adds dynamic dips to the side plank for more oblique engagement."
            },
            {
                "name": "Side Plank Rotations",
                "description": "Adds a rotational movement to the side plank for increased difficulty."
            },
            {
                "name": "Star Side Plank",
                "description": "Involves raising the top arm and leg for greater balance and strength."
            },
            {
                "name": "Side Plank Leg Abductions",
                "description": "Lifts the top leg during a side plank for additional challenge."
            },
            {
                "name": "Clam Shells",
                "description": "Targets hip abductors and core stabilization."
            },
            {
                "name": "Modified Side Plank Dips",
                "description": "Adds dips to the modified side plank for a dynamic challenge."
            }
        ],
        "Stretch": []
    },
    "Standing": {
        "Strength": [
            {
                "name": "Split Stance One Arm Shoulder Press",
                "description": "Overhead pressing while engaging core in a split stance."
            },
            {
                "name": "Wall Plank",
                "description": "A standing plank variation on elbows, challenging the core."
            },
            {
                "name": "Standing Ball Squeezes",
                "description": "Squeezing a ball between legs while standing to engage inner thighs and core."
            },
            {
                "name": "Tree Pose",
                "description": "A balance exercise involving core engagement while standing on one leg."
            },
            {
                "name": "Wall Push-up Shoulder Taps",
                "description": "Combines a wall push-up with alternating shoulder taps for upper body and core strength."
            },
            {
                "name": "Wall Mountain Climbers",
                "description": "A standing version of mountain climbers to engage the core while avoiding strain on the rectus abdominis."
            },
            {
                "name": "Farmer Carry",
                "description": "Core activation while walking with a dumbbell in one hand."
            },
            {
                "name": "Waiter Carry",
                "description": "An overhead variation of the farmer carry to strengthen the obliques and core."
            },
            {
                "name": "Standing Bicycles",
                "description": "A standing variation of traditional core exercises to minimize pressure on the rectus abdominis."
            },
            {
                "name": "Reverse Lunge",
                "description": "Strengthens legs and core while performing reverse lunges."
            }
        ],
        "Stretch": [
            {
                "name": "Wall Plank Stretch",
                "description": "A standing plank that doubles as a gentle core stretch while maintaining a safe position."
            }
        ]
    }
}
